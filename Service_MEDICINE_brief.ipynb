# %% [markdown]
# <a href="https://colab.research.google.com/github/gfhertlein/medical_smart_compose/blob/master/Service_MEDICINE_brief.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !pip install -r ./examples/requirements.txt
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 26170, done.
# remote: Total 26170 (delta 0), reused 0 (delta 0), pack-reused 26170
# Receiving objects: 100% (26170/26170), 15.31 MiB | 8.48 MiB/s, done.
# Resolving deltas: 100% (18286/18286), done.
# /content/transformers
# Processing /content/transformers
# ...
#      |████████████████████████████████| 3.8MB 2.7MB/s
# ...
#      |████████████████████████████████| 1.0MB 17.4MB/s
# ...
#      |████████████████████████████████| 890kB 28.4MB/s
# ...
#   Created wheel for transformers: filename=transformers-2.8.0-cp36-none-any.whl size=595729 sha256=a555fff685c4b26425ed2f4311b230db9ed7fdadebc6a0329460cb2f07e3d863
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rxcftua8/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.41-cp36-none-any.whl size=893334 sha256=612827bfbb2a8ea78b26fa975f9ce3e9e4642ca4cffbaa0649e750e5e3055a84
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd
Service_Hospital = pd.read_csv('/content/drive/My Drive/Data-X Project/Colab Notebooks/Service_Brief_Hospital_Course_Top5.csv')
Service_Hospital.shape
# Out:
# (9612, 3)

# %%
Service_Hospital['Service'].value_counts()
# Out:
# MEDICINE          6181
# CARDIOTHORACIC    1359
# SURGERY           1274
# NEUROLOGY          430
# NEUROSURGERY       368
# Name: Service, dtype: int64

# %%
Service_Medecine= Service_Hospital[Service_Hospital['Service']=='MEDICINE'].copy()

# %%
Service_Medecine=Service_Medecine['Brief Hospital Course'].copy()

# %%
Service_Medecine.head(3)
# Out:
# 0    87 yo F with h/o CHF, COPD on 5 L oxygen at ba...
# 1    Mr. [**Known lastname 1829**] was seen at [**H...
# 3    82 yo F with CAD, CHF, HTN, recent PE ([**10-1...
# Name: Brief Hospital Course, dtype: object

# %%
Service_Medecine_train= Service_Medecine.sample(frac=0.85, random_state=0)
Service_Medecine_test = Service_Medecine.drop(Service_Medecine_train.index)

# %%
Service_Medecine_test.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_Medecine_test.txt', header=None, index=None, sep='\t', mode='a')
Service_Medecine_train.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_Medecine_train.txt', header=None, index=None, sep='\t', mode='a')

# %%
# !python /content/transformers/examples/run_language_modeling.py\
    --output_dir='/content/drive/My Drive/Data-X Project/Colab Notebooks/Tests_GPT2/Service_Medecine_model' \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_Medecine_train.txt' \
    --do_eval \
    --eval_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_Medecine_test.txt' \
    --per_gpu_eval_batch_size 1 \
    --block_size 50 \
    --per_gpu_eval_batch_size 1 \
    --save_steps 3000
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Iteration:  99% 9480/9550 [15:37<00:06, 10.54it/s]
# Iteration:  99% 9482/9550 [15:37<00:06, 10.54it/s]
# Iteration:  99% 9484/9550 [15:37<00:06, 10.56it/s]
# Iteration:  99% 9486/9550 [15:37<00:06, 10.55it/s]
# Iteration:  99% 9488/9550 [15:37<00:05, 10.53it/s]
# Iteration:  99% 9490/9550 [15:38<00:05, 10.56it/s]
# Iteration:  99% 9492/9550 [15:38<00:05, 10.44it/s]
# Iteration:  99% 9494/9550 [15:38<00:05, 10.48it/s]
# Iteration:  99% 9496/9550 [15:38<00:05, 10.50it/s]
# Iteration:  99% 9498/9550 [15:38<00:04, 10.53it/s]
# Iteration:  99% 9500/9550 [15:39<00:04, 10.52it/s]
# Iteration:  99% 9502/9550 [15:39<00:04, 10.55it/s]
# Iteration: 100% 9504/9550 [15:39<00:04, 10.55it/s]
# Iteration: 100% 9506/9550 [15:39<00:04, 10.56it/s]
# Iteration: 100% 9508/9550 [15:39<00:03, 10.57it/s]
# Iteration: 100% 9510/9550 [15:40<00:03, 10.41it/s]
# Iteration: 100% 9512/9550 [15:40<00:03, 10.52it/s]
# ...
