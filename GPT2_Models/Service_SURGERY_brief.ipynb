# %% [markdown]
# <a href="https://colab.research.google.com/github/gfhertlein/medical_smart_compose/blob/master/Service_SURGERY_brief.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !pip install -r ./examples/requirements.txt
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 26170, done.
# remote: Total 26170 (delta 0), reused 0 (delta 0), pack-reused 26170
# Receiving objects: 100% (26170/26170), 15.31 MiB | 26.70 MiB/s, done.
# Resolving deltas: 100% (18285/18285), done.
# /content/transformers
# Processing /content/transformers
# ...
#      |████████████████████████████████| 3.8MB 2.7MB/s
# ...
#      |████████████████████████████████| 1.0MB 48.4MB/s
# ...
#      |████████████████████████████████| 890kB 47.0MB/s
# ...
#   Created wheel for transformers: filename=transformers-2.8.0-cp36-none-any.whl size=595729 sha256=ae6b58e299add6eb5e408cf2785b09e1547fa783d8e225dad5e0ce2ea8b9a22d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-edxoyvi3/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.41-cp36-none-any.whl size=893334 sha256=6d5df10d70417fa56fd9f107744fe68052910fd856a4a072ce91fa5df08e1b0d
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd
Service_Hospital = pd.read_csv('/content/drive/My Drive/Data-X Project/Colab Notebooks/Service_Brief_Hospital_Course_Top5.csv')
Service_Hospital.shape
# Out:
# (9612, 3)

# %%
Service_Hospital['Service'].value_counts()
# Out:
# MEDICINE          6181
# CARDIOTHORACIC    1359
# SURGERY           1274
# NEUROLOGY          430
# NEUROSURGERY       368
# Name: Service, dtype: int64

# %%
Service_SURGERY = Service_Hospital[Service_Hospital['Service']=='SURGERY'].copy()

# %%
Service_SURGERY =Service_SURGERY['Brief Hospital Course'].copy()

# %%
Service_SURGERY .head(3)
# Out:
# 12    On [**2130-2-3**] Mr. [**Known lastname 2302**...
# 14    70 y.o. male with hx of Crohn's disease, afib,...
# 17    75 year old man with CAD s/p CABD and ischemic...
# Name: Brief Hospital Course, dtype: object

# %%
Service_SURGERY_train= Service_SURGERY.sample(frac=0.85, random_state=0)
Service_SURGERY_test = Service_SURGERY.drop(Service_SURGERY_train.index)

# %%
Service_SURGERY_test.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_SURGERY_test.txt', header=None, index=None, sep='\t', mode='a')
Service_SURGERY_train.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_SURGERY_train.txt', header=None, index=None, sep='\t', mode='a')

# %%
#!pip install tensorflowjs

# %%
# !python /content/transformers/examples/run_language_modeling.py\
    --output_dir='/content/drive/My Drive/Data-X Project/Colab Notebooks/Tests_GPT2/Service_SURGERY_model' \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_SURGERY_train.txt' \
    --do_eval \
    --eval_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_SURGERY_test.txt' \
    --per_gpu_eval_batch_size 1 \
    --block_size 50 \
    --per_gpu_eval_batch_size 1 \
    --save_steps 1000 \
    --num_train_epochs 1
# Out:
# 2020-05-03 07:17:43.502014: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 05/03/2020 07:17:45 - INFO - transformers.training_args -   PyTorch: setting up devices
# 05/03/2020 07:17:45 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# ...
