# %% [markdown]
# <a href="https://colab.research.google.com/github/gfhertlein/medical_smart_compose/blob/master/Service_CARDIOTHORACIC_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !pip install -r ./examples/requirements.txt
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 26170, done.
# remote: Total 26170 (delta 0), reused 0 (delta 0), pack-reused 26170
# Receiving objects: 100% (26170/26170), 15.31 MiB | 30.56 MiB/s, done.
# Resolving deltas: 100% (18285/18285), done.
# /content/transformers
# Processing /content/transformers
# ...
#      |████████████████████████████████| 3.8MB 3.4MB/s
# ...
#      |████████████████████████████████| 1.0MB 28.3MB/s
# ...
#      |████████████████████████████████| 890kB 47.2MB/s
# ...
#   Created wheel for transformers: filename=transformers-2.8.0-cp36-none-any.whl size=595729 sha256=1ff18d2b8c27d2b1efd1128ed2ea8f6bd1ebccb61d25162d36b3a9716821e968
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4m4yg6vm/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.41-cp36-none-any.whl size=893334 sha256=dcf763e781f6545305b89a4d5be563d6ed5e565497c10c353dc94251cabb94b6
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd
Service_Hospital = pd.read_csv('/content/drive/My Drive/Data-X Project/Colab Notebooks/Service_Brief_Hospital_Course_Top5.csv')
Service_Hospital.shape
# Out:
# (9612, 3)

# %%
Service_Hospital['Service'].value_counts()
# Out:
# MEDICINE          6181
# CARDIOTHORACIC    1359
# SURGERY           1274
# NEUROLOGY          430
# NEUROSURGERY       368
# Name: Service, dtype: int64

# %%
Service_CARDIOTHORACIC= Service_Hospital[Service_Hospital['Service']=='CARDIOTHORACIC'].copy()

# %%
Service_CARDIOTHORACIC=Service_CARDIOTHORACIC['Brief Hospital Course'].copy()

# %%
Service_CARDIOTHORACIC.head(3)
# Out:
# 28    . # Dyspnea: Her shortness of breath and respi...
# 47    A/P:  54 woman on immunosuppressive therapy fo...
# 55    64 year-old male with history of lung cancer p...
# Name: Brief Hospital Course, dtype: object

# %%
Service_CARDIOTHORACIC_train= Service_CARDIOTHORACIC.sample(frac=0.85, random_state=0)
Service_CARDIOTHORACIC_test = Service_CARDIOTHORACIC.drop(Service_CARDIOTHORACIC_train.index)

# %%
Service_CARDIOTHORACIC_test.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_CARDIOTHORACIC_test.txt', header=None, index=None, sep='\t', mode='a')
Service_CARDIOTHORACIC_train.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_CARDIOTHORACIC_train.txt', header=None, index=None, sep='\t', mode='a')

# %%
# !python /content/transformers/examples/run_language_modeling.py\
    --output_dir='/content/drive/My Drive/Data-X Project/Colab Notebooks/Tests_GPT2/Service_CARDIOTHORACIC_model' \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_CARDIOTHORACIC_train.txt' \
    --do_eval \
    --eval_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/Service_CARDIOTHORACIC_test.txt' \
    --per_gpu_eval_batch_size 1 \
    --block_size 50 \
    --per_gpu_eval_batch_size 1 \
    --save_steps 1500
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Iteration:  78% 3259/4196 [05:25<01:28, 10.63it/s]
# Iteration:  78% 3261/4196 [05:25<01:27, 10.63it/s]
# Iteration:  78% 3263/4196 [05:26<01:27, 10.64it/s]
# Iteration:  78% 3265/4196 [05:26<01:27, 10.61it/s]
# Iteration:  78% 3267/4196 [05:26<01:27, 10.63it/s]
# Iteration:  78% 3269/4196 [05:26<01:27, 10.62it/s]
# Iteration:  78% 3271/4196 [05:26<01:27, 10.62it/s]
# Iteration:  78% 3273/4196 [05:27<01:26, 10.63it/s]
# Iteration:  78% 3275/4196 [05:27<01:26, 10.60it/s]
# Iteration:  78% 3277/4196 [05:27<01:26, 10.61it/s]
# Iteration:  78% 3279/4196 [05:27<01:26, 10.63it/s]
# Iteration:  78% 3281/4196 [05:27<01:26, 10.63it/s]
# Iteration:  78% 3283/4196 [05:28<01:25, 10.63it/s]
# Iteration:  78% 3285/4196 [05:28<01:25, 10.64it/s]
# Iteration:  78% 3287/4196 [05:28<01:25, 10.64it/s]
# Iteration:  78% 3289/4196 [05:28<01:25, 10.64it/s]
# Iteration:  78% 3291/4196 [05:28<01:25, 10.63it/s]
# ...
