# %% [markdown]
# <a href="https://colab.research.google.com/github/gfhertlein/medical_smart_compose/blob/master/rawGPT2_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/transformers
# %cd transformers
# !pip install .
# !pip install -r ./examples/requirements.txt
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 24177 (delta 41), reused 38 (delta 19), pack-reused 24089
# Receiving objects: 100% (24177/24177), 14.45 MiB | 15.48 MiB/s, done.
# Resolving deltas: 100% (17099/17099), done.
# /content/transformers
# Processing /content/transformers
# ...
#      |████████████████████████████████| 3.8MB 8.2MB/s
# ...
#      |████████████████████████████████| 1.0MB 59.6MB/s
# ...
#      |████████████████████████████████| 890kB 51.8MB/s
# ...
#   Created wheel for transformers: filename=transformers-2.8.0-cp36-none-any.whl size=565559 sha256=ee9c3f7c9a414d41937a0da7d33b6249cca09d4705032d291131760772fe5fa3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cgzh0ge4/wheels/23/19/dd/2561a4e47240cf6b307729d58e56f8077dd0c698f5992216cf
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/RawData_ 4:14.csv')

# %%
df.shape
# Out:
# (5000, 1)

# %%
train_set = df.sample(frac=0.80, random_state=0)
test_set = df.drop(train_set.index)

# %%
train_set.shape
# Out:
# (4000, 1)

# %%
test_set.shape
# Out:
# (1000, 1)

# %%
import numpy as np

train_set.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/raw_train_data.txt', header=None, index=None, sep='\t', mode='a')
test_set.to_csv(r'/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/raw_test_data.txt', header=None, index=None, sep='\t', mode='a')

# %%
test_file ='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/raw_test_data.txt'
train_file = '/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/raw_train_data.txt'

# %%
# !python /content/transformers/examples/run_language_modeling.py\
    --output_dir='/content/drive/My Drive/Data-X Project/Colab Notebooks/Tests_GPT2/Raw_GPT2_model' \
    --model_type=gpt2 \
    --model_name_or_path=gpt2 \
    --do_train \
    --train_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/raw_train_data.txt' \
    --do_eval \
    --eval_data_file='/content/drive/My Drive/Data-X Project/Colab Notebooks/Data/raw_test_data.txt' \
    --per_gpu_eval_batch_size 1 \
    --block_size 256
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Iteration:  65% 8854/13600 [52:01<26:39,  2.97it/s]
# Iteration:  65% 8855/13600 [52:02<26:40,  2.96it/s]
# Iteration:  65% 8856/13600 [52:02<26:36,  2.97it/s]
# Iteration:  65% 8857/13600 [52:02<26:36,  2.97it/s]
# Iteration:  65% 8858/13600 [52:03<26:33,  2.98it/s]
# Iteration:  65% 8859/13600 [52:03<26:31,  2.98it/s]
# Iteration:  65% 8860/13600 [52:03<26:35,  2.97it/s]
# Iteration:  65% 8861/13600 [52:04<26:36,  2.97it/s]
# Iteration:  65% 8862/13600 [52:04<26:34,  2.97it/s]
# Iteration:  65% 8863/13600 [52:04<26:34,  2.97it/s]
# Iteration:  65% 8864/13600 [52:05<26:33,  2.97it/s]
# Iteration:  65% 8865/13600 [52:05<26:32,  2.97it/s]
# Iteration:  65% 8866/13600 [52:05<26:31,  2.98it/s]
# Iteration:  65% 8867/13600 [52:06<26:34,  2.97it/s]
# Iteration:  65% 8868/13600 [52:06<26:33,  2.97it/s]
# Iteration:  65% 8869/13600 [52:06<26:32,  2.97it/s]
# Iteration:  65% 8870/13600 [52:07<26:35,  2.96it/s]
# ...
